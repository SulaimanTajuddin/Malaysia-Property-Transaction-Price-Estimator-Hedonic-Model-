# %% [markdown]
# <a href="https://colab.research.google.com/github/SulaimanTajuddin/Malaysia-Property-Transaction-Price-Estimator-Hedonic-Model-/blob/main/MY_Property_Transaction_Price_Estimator_(HM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
sulaimantajuddin_malaysia_mixed_property_transaction_data_path = kagglehub.dataset_download('sulaimantajuddin/malaysia-mixed-property-transaction-data')

print('Data source import complete.')

# %% [markdown]
# # Malaysia Property Transaction Price Estimator (Hedonic Model)

# %%
import chardet
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the dataset:

# %%
train_file_path = "../input/datasets/sulaimantajuddin/malaysia-mixed-property-transaction-data/2026 NAPIC - Open Transaction Data  (270226).csv"
df = pd.read_csv(train_file_path, encoding='utf-16', sep='\t')
print("Full train dataset shape is {}".format(df.shape))

# %% [markdown]
# Analyze the raw data:

# %%
df.head

# %%
df.info()

# %%
msno.bar(df)

# %%
msno.matrix(df)
